# %%
import matplotlib.pyplot as plt
from sklearn.svm import SVC
import numpy as np
import os
from skimage.feature import hog
from skimage.color import rgb2gray

# %% [markdown]
# Chargement des données d'entraînement

# %%
# Chargement des données des patchs normalisés
pos_patch_fs = [
    os.path.splitext(f)[0]
    for f in os.listdir(os.path.join("local_data", "4_normalized_patches", "pos"))
    if f.endswith(".jpg")
]
neg_patch_fs = [
    os.path.splitext(f)[0]
    for f in os.listdir(os.path.join("local_data", "4_normalized_patches", "neg"))
    if f.endswith(".jpg")
]

pos_patchs = []
neg_patchs = []

for f in pos_patch_fs:
    try:
        patch = plt.imread(
            os.path.join("local_data", "4_normalized_patches", "pos", f"{f}.jpg")
        )
        pos_patchs.append(patch[
            :, :, 0
        ])  # le channel grayscale est dupliqué sur les 3 chanaux RGB (on en isole 1)

    except FileNotFoundError:
        continue

for f in neg_patch_fs:
    try:
        patch = plt.imread(
            os.path.join("local_data", "4_normalized_patches", "neg", f"{f}.jpg")
        )
        neg_patchs.append(patch[
            :, :, 0
        ])  # le channel grayscale est dupliqué sur les 3 chanaux RGB (on en isole 1)

    except FileNotFoundError:
        continue

nb_patchs_tot = len(pos_patchs) + len(neg_patchs)
print(len(pos_patchs))
print(len(neg_patchs))
# Out:
# 1204
# 6020

# %%
# Chargement des images de test
imgs_test_f = [
    os.path.splitext(f)[0]
    for f in os.listdir(
        os.path.join("data", "test")
    )
    if f.endswith(".jpg")
]

imgs_test = {}
imgs_test_rgb = {}

for f in imgs_test_f:
    try:
        img = plt.imread(
            os.path.join(
                "data", "test", f"{f}.jpg"
            )
        )
        imgs_test[f] = rgb2gray(img)
        imgs_test_rgb[f] = img
    except FileNotFoundError:
        continue

print(len(imgs_test))
# Out:
# 82

# %%
y_train = np.hstack(
    [np.ones((1, len(pos_patchs))), np.zeros((1, len(neg_patchs)))]
).flatten()

patchs_train = np.array(pos_patchs + neg_patchs)
print(patchs_train.shape)
print(y_train.shape)
# Out:
# (7224, 128, 72)
# (7224,)

# %%
# Extraction des features sur les patchs d'entraînement
# TODO : y placer les paramètres optimisés


def HOG_extractor(patchs):
    if len(patchs) == 0:
        return []
    first_features = hog(patchs[0])  # valeurs par défaut
    features = np.zeros(
        shape=(len(patchs), first_features.shape[0]), dtype=first_features.dtype
    )
    for i, patch in enumerate(patchs):
        features[i] = hog(patch)

    return features


X_train = HOG_extractor(patchs_train)
print(X_train.shape)
print(X_train.dtype)
# Out:
# (7224, 7938)
# float64

# %%
# Entraînement du modèle
# TODO : y placer les paramètres optimisés
# probability=True pour pouvoir utiliser .predict_proba(X) dessus (rajoute pas mal de temps d'entraînement en vrai)

clf = SVC(kernel="poly", probability=True)
clf.fit(X_train, y_train)
# Out:
# SVC(kernel='poly', probability=True)

# %% [markdown]
# Autres trucs utiles

# %%
stats = {}
with open(
    os.path.join("local_data", "4_normalized_patches", "stats.txt"),
    "r",
    encoding="utf-8",
) as f:
    for line in f:
        line = line.strip()
        if not line or "=" not in line:
            continue

        key, value = line.split("=", 1)

        try:
            val = float(value)
            if val.is_integer():
                val = int(val)
            stats[key] = val
        except ValueError:
            pass

# Extraction dans des variables individuelles (optionnel)
min_ratio = stats.get("min_ratio")
max_ratio = stats.get("max_ratio")
moy_ratio = stats.get("moy_ratio")
min_scale = stats.get("min_scale")
max_scale = stats.get("max_scale")

print(min_ratio)
print(max_ratio)
print(moy_ratio)
print(min_scale)
print(max_scale)
# Out:
# 0.42758620689655175
# 0.9832214765100671
# 0.5726107997574511
# 107
# 967

# %% [markdown]
# Explication des variables utiles à la détection

# %%
### Essentiels

imgs_test       # liste python des images de test (qui sont déjà grayscale, chaque image est une numpy array 2D)
imgs_test_rgb   # même chose mais en RGB (pour visualisation)

clf  # Le classifieur SVC(kernel="poly") entraîné avec les features extraites grâce à un HOG sur tous les patchs d'entraînement

### Limites de formes des fenêtres de découpe

min_scale  # facteur de scale minimum mesuré dans les bbox d'annotations sur les images positives (c'est-à-dire la longueur du rectangle)
max_scale  # facteur de scale max

min_ratio  # ratio minimum mesuré (rapport entre largeur/hauteur), un ratio petit fait que la fenêtre apparâit plus "carrée"
max_ratio  # ratio maximum mesuré

# Exemple pour obtenir les dimensions de la plus grande fenêtre de test :
# (max_ratio*max_scale, max_scale) : (width, height), la fenêtre apparaît comme un rectangle "debout"
# il faudrait aussi tester le cas inverse :
# (max_scale, max_ratio*max_scale) : (width, height), la fenêtre apparaît comme un rectangle "allongé"


### Traitement des patchs
HOG_extractor  # fonction qui prend une liste ou array de patchs normalisés et extrait les features (pour fabriquer X_test pour soumission à la prédiction du classifieur)
# Out:
# <function __main__.HOG_extractor(patchs)>

# %%
import importlib

import utils.detection
importlib.reload(utils.detection)
detect_ecocup = utils.detection.detect_ecocup

test_windows = {} # dictionnaire {"num_img": liste des fenêtres détectées avec p>0.5}
test_scores = {}  # dictionnaire {"num_img": liste des scores de confiance des fenêtres détectées}

for img_name, img in imgs_test.items():
    print(f"\n---------Traitement de l'image {img_name}---------\n")
    all_windows, all_scores = detect_ecocup(
        img, clf, HOG_extractor, min_ratio, max_ratio, min_scale, max_scale,
        px_step=35, scales_nb=10, ratios_nb=5, confidence_threshold=0.5
    )
    test_windows[img_name] = all_windows.tolist()
    test_scores[img_name] = all_scores.tolist()

# Sauvegarde des résultats de détection dans des jsons
import json
with open(os.path.join("test_data", "test_windows.json"), "w") as f:
      json.dump(test_windows, f)
with open(os.path.join("test_data", "test_scores.json"), "w") as f:
      json.dump(test_scores, f)
# Out:
# ---------Traitement de l'image 0000---------
#
# Temps setup : 0.0
# Nombre d'itérations : 50
#
# 	Itération 1 : h=0107 | w=0045
# 	Temps sliding_window x2 (2886 généré): 0.004036664962768555
# 	Temps de traitement pour 2886 : 0.5307772159576416
# 	Temps d'extraction de features pour 2886 : 4.2225635051727295
# 	Temps de prédiction pour 2886 : 12.480963945388794
# 	Fenêtres gardées : 2 sur 2886 (p>=0.5)
# 	Meilleur score de l'itération : 0.913285009636576 pour [[490 210]
#  [535 317]]
# 	Temps cumulé : 17.238341331481934
#
# 	Itération 2 : h=0202 | w=0086
# 	Temps sliding_window x2 (2660 généré): 0.0029909610748291016
# 	Temps de traitement pour 2660 : 0.8198337554931641
# 	Temps d'extraction de features pour 2660 : 4.081993818283081
# 	Temps de prédiction pour 2660 : 12.076321363449097
# 	Fenêtres gardées : 1 sur 2660 (p>=0.5)
# 	Meilleur score de l'itération : 0.6137753333925393 pour [[420 280]
#  [506 482]]
# 	Temps cumulé : 34.219481229782104
#
# 	Itération 3 : h=0298 | w=0127
# 	Temps sliding_window x2 (2368 généré): 0.0028107166290283203
# 	Temps de traitement pour 2368 : 0.9489367008209229
# 	Temps d'extraction de features pour 2368 : 3.78790020942688
# 	Temps de prédiction pour 2368 : 10.282258033752441
# 	Fenêtres gardées : 27 sur 2368 (p>=0.5)
# 	Meilleur score de l'itération : 0.9333699176730686 pour [[595 140]
#  [722 438]]
# 	Temps cumulé : 49.24138689041138
#
# 	Itération 4 : h=0393 | w=0168
# 	Temps sliding_window x2 (2088 généré): 0.0026307106018066406
# 	Temps de traitement pour 2088 : 1.121457815170288
# 	Temps d'extraction de features pour 2088 : 3.211933135986328
# 	Temps de prédiction pour 2088 : 9.083786725997925
# 	Fenêtres gardées : 10 sur 2088 (p>=0.5)
# 	Meilleur score de l'itération : 0.9912687690434183 pour [[420 140]
#  [588 533]]
# 	Temps cumulé : 62.661195278167725
#
# 	Itération 5 : h=0489 | w=0209
# 	Temps sliding_window x2 (1890 généré): 0.002099752426147461
# 	Temps de traitement pour 1890 : 1.775904893875122
# 	Temps d'extraction de features pour 1890 : 2.9847517013549805
# 	Temps de prédiction pour 1890 : 8.298274040222168
# 	Fenêtres gardées : 2 sur 1890 (p>=0.5)
# 	Meilleur score de l'itération : 0.7102957534489426 pour [[385 140]
#  [594 629]]
# 	Temps cumulé : 75.72470378875732
#
# 	Itération 6 : h=0584 | w=0249
# 	Temps sliding_window x2 (1584 généré): 0.0010933876037597656
# 	Temps de traitement pour 1584 : 2.7472474575042725
# 	Temps d'extraction de features pour 1584 : 3.0704329013824463
# 	Temps de prédiction pour 1584 : 7.149237871170044
# 	Fenêtres gardées : 5 sur 1584 (p>=0.5)
# 	Meilleur score de l'itération : 0.914689443429046 pour [[315 140]
#  [564 724]]
# 	Temps cumulé : 88.6942789554596
#
# 	Itération 7 : h=0680 | w=0290
# 	Temps sliding_window x2 (1344 généré): 0.0038809776306152344
# 	Temps de traitement pour 1344 : 3.0326449871063232
# 	Temps d'extraction de features pour 1344 : 2.0435712337493896
# 	Temps de prédiction pour 1344 : 5.734950065612793
# 	Fenêtres gardées : 12 sur 1344 (p>=0.5)
# 	Meilleur score de l'itération : 0.9863061154096133 pour [[ 315  595]
#  [ 605 1275]]
# 	Temps cumulé : 99.50932621955872
#
# 	Itération 8 : h=0775 | w=0331
# 	Temps sliding_window x2 (1116 généré): 0.001081705093383789
# 	Temps de traitement pour 1116 : 3.265500545501709
# 	Temps d'extraction de features pour 1116 : 1.6532988548278809
# 	Temps de prédiction pour 1116 : 4.6548991203308105
# 	Fenêtres gardées : 3 sur 1116 (p>=0.5)
# 	Meilleur score de l'itération : 0.7280811187470182 pour [[ 35   0]
#  [366 775]]
# 	Temps cumulé : 109.0841064453125
#
# 	Itération 9 : h=0871 | w=0372
# 	Temps sliding_window x2 (960 généré): 0.0010116100311279297
# 	Temps de traitement pour 960 : 3.609980821609497
# 	Temps d'extraction de features pour 960 : 1.4255857467651367
# 	Temps de prédiction pour 960 : 4.005658864974976
# 	Fenêtres gardées : 1 sur 960 (p>=0.5)
# 	Meilleur score de l'itération : 0.6695744782939947 pour [[ 245  140]
#  [ 617 1011]]
# 	Temps cumulé : 118.12734246253967
#
# 	Itération 10 : h=0967 | w=0413
# 	Temps sliding_window x2 (754 généré): 0.0
# 	Temps de traitement pour 754 : 3.8035593032836914
# 	Temps d'extraction de features pour 754 : 1.1397602558135986
# 	Temps de prédiction pour 754 : 3.2121176719665527
# 	Fenêtres gardées : 2 sur 754 (p>=0.5)
# 	Meilleur score de l'itération : 0.6355959504598881 pour [[ 770  385]
#  [1183 1352]]
# 	Temps cumulé : 126.28277969360352
#
# 	Itération 11 : h=0107 | w=0060
# 	Temps sliding_window x2 (2886 généré): 0.0031659603118896484
# 	Temps de traitement pour 2886 : 0.5759158134460449
# 	Temps d'extraction de features pour 2886 : 4.326169490814209
# 	Temps de prédiction pour 2886 : 12.311139106750488
# 	Fenêtres gardées : 3 sur 2886 (p>=0.5)
# 	Meilleur score de l'itération : 0.7943004057274126 pour [[140 630]
#  [247 690]]
# 	Temps cumulé : 143.50353741645813
#
# 	Itération 12 : h=0202 | w=0114
# 	Temps sliding_window x2 (2590 généré): 0.0
# 	Temps de traitement pour 2590 : 0.8624911308288574
# 	Temps d'extraction de features pour 2590 : 4.178125858306885
# 	Temps de prédiction pour 2590 : 12.003301620483398
# 	Fenêtres gardées : 2 sur 2590 (p>=0.5)
# 	Meilleur score de l'itération : 0.9172115240840806 pour [[455 665]
#  [569 867]]
# 	Temps cumulé : 160.54745602607727
#
# 	Itération 13 : h=0298 | w=0168
# 	Temps sliding_window x2 (2304 généré): 0.0036618709564208984
# 	Temps de traitement pour 2304 : 1.0834357738494873
# 	Temps d'extraction de features pour 2304 : 3.645303964614868
# 	Temps de prédiction pour 2304 : 9.693357229232788
# 	Fenêtres gardées : 9 sur 2304 (p>=0.5)
# 	Meilleur score de l'itération : 0.8151637395678624 pour [[105 350]
#  [273 648]]
# 	Temps cumulé : 174.97321486473083
#
# 	Itération 14 : h=0393 | w=0222
# 	Temps sliding_window x2 (1972 généré): 0.0
# 	Temps de traitement pour 1972 : 1.3757593631744385
# 	Temps d'extraction de features pour 1972 : 3.078134298324585
# 	Temps de prédiction pour 1972 : 8.400848865509033
# 	Fenêtres gardées : 6 sur 1972 (p>=0.5)
# 	Meilleur score de l'itération : 0.9545848969442479 pour [[385 140]
#  [607 533]]
# 	Temps cumulé : 187.82873010635376
#
# 	Itération 15 : h=0489 | w=0277
# 	Temps sliding_window x2 (1782 généré): 0.010552167892456055
# 	Temps de traitement pour 1782 : 2.4716317653656006
# 	Temps d'extraction de features pour 1782 : 2.7398626804351807
# 	Temps de prédiction pour 1782 : 7.456645250320435
# 	Fenêtres gardées : 5 sur 1782 (p>=0.5)
# 	Meilleur score de l'itération : 0.9926253503785358 pour [[315 140]
#  [592 629]]
# 	Temps cumulé : 200.50742197036743
#
# 	Itération 16 : h=0584 | w=0330
# 	Temps sliding_window x2 (1488 généré): 0.0008819103240966797
# 	Temps de traitement pour 1488 : 3.0410959720611572
# 	Temps d'extraction de features pour 1488 : 2.3131918907165527
# 	Temps de prédiction pour 1488 : 6.119501829147339
# 	Fenêtres gardées : 2 sur 1488 (p>=0.5)
# 	Meilleur score de l'itération : 0.6936009816733919 pour [[280 140]
#  [610 724]]
# 	Temps cumulé : 211.98209357261658
#
# 	Itération 17 : h=0680 | w=0385
# 	Temps sliding_window x2 (1260 généré): 0.0
# 	Temps de traitement pour 1260 : 3.9996497631073
# 	Temps d'extraction de features pour 1260 : 1.9203932285308838
# 	Temps de prédiction pour 1260 : 5.161823987960815
# 	Fenêtres gardées : 1 sur 1260 (p>=0.5)
# 	Meilleur score de l'itération : 0.5558763189031818 pour [[   0  630]
#  [ 385 1310]]
# 	Temps cumulé : 223.06396055221558
#
# 	Itération 18 : h=0775 | w=0439
# 	Temps sliding_window x2 (1008 généré): 0.001069784164428711
# 	Temps de traitement pour 1008 : 4.186458349227905
# 	Temps d'extraction de features pour 1008 : 1.542064905166626
# 	Temps de prédiction pour 1008 : 4.130357265472412
# 	Fenêtres gardées : 1 sur 1008 (p>=0.5)
# 	Meilleur score de l'itération : 0.6427896049980559 pour [[ 770  385]
#  [1209 1160]]
# 	Temps cumulé : 232.92391085624695
#
# 	Itération 19 : h=0871 | w=0493
# 	Temps sliding_window x2 (832 généré): 0.0009989738464355469
# 	Temps de traitement pour 832 : 4.636962890625
# 	Temps d'extraction de features pour 832 : 1.289219856262207
# 	Temps de prédiction pour 832 : 3.4176580905914307
# 	Fenêtres gardées : 0 sur 832 (p>=0.5)
# 	Meilleur score de l'itération : 0.4588232908769022 pour [[ 700  420]
#  [1193 1291]]
# 	Temps cumulé : 242.26875066757202
#
# 	Itération 20 : h=0967 | w=0547
# 	Temps sliding_window x2 (650 généré): 0.0005764961242675781
# 	Temps de traitement pour 650 : 4.775666236877441
# 	Temps d'extraction de features pour 650 : 1.0073950290679932
# 	Temps de prédiction pour 650 : 2.6911489963531494
# 	Fenêtres gardées : 0 sur 650 (p>=0.5)
# 	Meilleur score de l'itération : 0.4538579559928467 pour [[ 665  385]
#  [1212 1352]]
# 	Temps cumulé : 250.7448434829712
#
# 	Itération 21 : h=0107 | w=0075
# 	Temps sliding_window x2 (2812 généré): 0.002634286880493164
# 	Temps de traitement pour 2812 : 0.6168110370635986
# 	Temps d'extraction de features pour 2812 : 4.42230486869812
# 	Temps de prédiction pour 2812 : 11.606852054595947
# 	Fenêtres gardées : 3 sur 2812 (p>=0.5)
# 	Meilleur score de l'itération : 0.5837203244828575 pour [[ 455 1260]
#  [ 562 1335]]
# 	Temps cumulé : 267.3944408893585
#
# 	Itération 22 : h=0202 | w=0142
# 	Temps sliding_window x2 (2520 généré): 0.0008859634399414062
# 	Temps de traitement pour 2520 : 0.8312633037567139
# 	Temps d'extraction de features pour 2520 : 3.965467691421509
# 	Temps de prédiction pour 2520 : 10.317932367324829
# 	Fenêtres gardées : 6 sur 2520 (p>=0.5)
# 	Meilleur score de l'itération : 0.7261158729681249 pour [[595 140]
#  [737 342]]
# 	Temps cumulé : 282.5099902153015
#
# 	Itération 23 : h=0298 | w=0210
# 	Temps sliding_window x2 (2240 généré): 0.014862060546875
# 	Temps de traitement pour 2240 : 1.2352275848388672
# 	Temps d'extraction de features pour 2240 : 3.5266294479370117
# 	Temps de prédiction pour 2240 : 9.208952903747559
# 	Fenêtres gardées : 0 sur 2240 (p>=0.5)
# 	Meilleur score de l'itération : 0.4231574297073077 pour [[525 140]
#  [735 438]]
# 	Temps cumulé : 296.4956622123718
#
# 	Itération 24 : h=0393 | w=0277
# 	Temps sliding_window x2 (1914 généré): 0.0
# 	Temps de traitement pour 1914 : 1.7289221286773682
# 	Temps d'extraction de features pour 1914 : 2.8829262256622314
# 	Temps de prédiction pour 1914 : 7.953282117843628
# 	Fenêtres gardées : 5 sur 1914 (p>=0.5)
# 	Meilleur score de l'itération : 0.986265527269148 pour [[315 140]
#  [592 533]]
# 	Temps cumulé : 309.06079268455505
#
# 	Itération 25 : h=0489 | w=0344
# 	Temps sliding_window x2 (1674 généré): 0.002051115036010742
# 	Temps de traitement pour 1674 : 2.722926378250122
# 	Temps d'extraction de features pour 1674 : 2.5058045387268066
# 	Temps de prédiction pour 1674 : 6.875930309295654
# 	Fenêtres gardées : 3 sur 1674 (p>=0.5)
# 	Meilleur score de l'itération : 0.7312418455097633 pour [[  35  840]
#  [ 379 1329]]
# 	Temps cumulé : 321.16750502586365
#
# 	Itération 26 : h=0584 | w=0411
# 	Temps sliding_window x2 (1392 généré): 0.0
# 	Temps de traitement pour 1392 : 3.7581162452697754
# 	Temps d'extraction de features pour 1392 : 2.060405731201172
# 	Temps de prédiction pour 1392 : 5.683161735534668
# 	Fenêtres gardées : 1 sur 1392 (p>=0.5)
# 	Meilleur score de l'itération : 0.5276896737206815 pour [[315 140]
#  [726 724]]
# 	Temps cumulé : 332.6701817512512
#
# 	Itération 27 : h=0680 | w=0479
# 	Temps sliding_window x2 (1134 généré): 0.0
# 	Temps de traitement pour 1134 : 4.42435359954834
# 	Temps d'extraction de features pour 1134 : 1.6954412460327148
# 	Temps de prédiction pour 1134 : 4.6289544105529785
# 	Fenêtres gardées : 0 sur 1134 (p>=0.5)
# 	Meilleur score de l'itération : 0.29433409934607235 pour [[ 770  560]
#  [1249 1240]]
# 	Temps cumulé : 343.4192235469818
#
# 	Itération 28 : h=0775 | w=0546
# 	Temps sliding_window x2 (900 généré): 0.0010714530944824219
# 	Temps de traitement pour 900 : 5.089493274688721
# 	Temps d'extraction de features pour 900 : 1.3511934280395508
# 	Temps de prédiction pour 900 : 3.686155319213867
# 	Fenêtres gardées : 0 sur 900 (p>=0.5)
# 	Meilleur score de l'itération : 0.21027810692036583 pour [[ 805   70]
#  [1351  845]]
# 	Temps cumulé : 353.54772424697876
#
# 	Itération 29 : h=0871 | w=0614
# 	Temps sliding_window x2 (736 généré): 0.0
# 	Temps de traitement pour 736 : 5.789687395095825
# 	Temps d'extraction de features pour 736 : 1.0916833877563477
# 	Temps de prédiction pour 736 : 3.076005220413208
# 	Fenêtres gardées : 0 sur 736 (p>=0.5)
# 	Meilleur score de l'itération : 0.16516026904121084 pour [[   0  315]
#  [ 614 1186]]
# 	Temps cumulé : 363.50510025024414
#
# 	Itération 30 : h=0967 | w=0682
# 	Temps sliding_window x2 (546 généré): 0.0009949207305908203
# 	Temps de traitement pour 546 : 5.463549613952637
# 	Temps d'extraction de features pour 546 : 0.7973198890686035
# 	Temps de prédiction pour 546 : 2.3032760620117188
# 	Fenêtres gardées : 0 sur 546 (p>=0.5)
# 	Meilleur score de l'itération : 0.16202044462597734 pour [[ 560  385]
#  [1242 1352]]
# 	Temps cumulé : 372.0712456703186
#
# 	Itération 31 : h=0107 | w=0090
# 	Temps sliding_window x2 (2812 généré): 0.0
# 	Temps de traitement pour 2812 : 0.6221635341644287
# 	Temps d'extraction de features pour 2812 : 4.200132131576538
# 	Temps de prédiction pour 2812 : 11.674728155136108
# 	Fenêtres gardées : 2 sur 2812 (p>=0.5)
# 	Meilleur score de l'itération : 0.8765559415126268 pour [[840 420]
#  [947 510]]
# 	Temps cumulé : 388.56927013397217
#
# 	Itération 32 : h=0202 | w=0170
# 	Temps sliding_window x2 (2520 généré): 0.0018610954284667969
# 	Temps de traitement pour 2520 : 0.9097025394439697
# 	Temps d'extraction de features pour 2520 : 3.8576858043670654
# 	Temps de prédiction pour 2520 : 10.330689191818237
# 	Fenêtres gardées : 6 sur 2520 (p>=0.5)
# 	Meilleur score de l'itération : 0.6874240720229269 pour [[350 175]
#  [552 345]]
# 	Temps cumulé : 403.6820139884949
#
# 	Itération 33 : h=0298 | w=0251
# 	Temps sliding_window x2 (2112 généré): 0.0
# 	Temps de traitement pour 2112 : 1.3654499053955078
# 	Temps d'extraction de features pour 2112 : 3.212827205657959
# 	Temps de prédiction pour 2112 : 8.665785074234009
# 	Fenêtres gardées : 2 sur 2112 (p>=0.5)
# 	Meilleur score de l'itération : 0.5684026202045218 pour [[315 140]
#  [613 391]]
# 	Temps cumulé : 416.92607617378235
#
# 	Itération 34 : h=0393 | w=0331
# 	Temps sliding_window x2 (1798 généré): 0.0020673274993896484
# 	Temps de traitement pour 1798 : 2.1549859046936035
# 	Temps d'extraction de features pour 1798 : 2.7248024940490723
# 	Temps de prédiction pour 1798 : 7.511441469192505
# 	Fenêtres gardées : 2 sur 1798 (p>=0.5)
# 	Meilleur score de l'itération : 0.9670493902634808 pour [[  35  875]
#  [ 366 1268]]
# 	Temps cumulé : 429.3204107284546
#
# 	Itération 35 : h=0489 | w=0412
# 	Temps sliding_window x2 (1566 généré): 0.0010592937469482422
# 	Temps de traitement pour 1566 : 3.523571491241455
# 	Temps d'extraction de features pour 1566 : 2.348231315612793
# 	Temps de prédiction pour 1566 : 6.530680894851685
# 	Fenêtres gardées : 0 sur 1566 (p>=0.5)
# 	Meilleur score de l'itération : 0.24544862818496918 pour [[ 770  525]
#  [1182 1014]]
# 	Temps cumulé : 441.7259843349457
#
# 	Itération 36 : h=0584 | w=0493
# 	Temps sliding_window x2 (1248 généré): 0.0010752677917480469
# 	Temps de traitement pour 1248 : 4.365738153457642
# 	Temps d'extraction de features pour 1248 : 1.8747820854187012
# 	Temps de prédiction pour 1248 : 5.157021760940552
# 	Fenêtres gardées : 1 sur 1248 (p>=0.5)
# 	Meilleur score de l'itération : 0.5318066562666002 pour [[245 140]
#  [738 724]]
# 	Temps cumulé : 453.1246016025543
#
# 	Itération 37 : h=0680 | w=0574
# 	Temps sliding_window x2 (1008 généré): 0.0009438991546630859
# 	Temps de traitement pour 1008 : 5.482372045516968
# 	Temps d'extraction de features pour 1008 : 1.5415222644805908
# 	Temps de prédiction pour 1008 : 4.157768487930298
# 	Fenêtres gardées : 1 sur 1008 (p>=0.5)
# 	Meilleur score de l'itération : 0.5134693499392183 pour [[ 805    0]
#  [1379  680]]
# 	Temps cumulé : 464.30720829963684
#
# 	Itération 38 : h=0775 | w=0654
# 	Temps sliding_window x2 (792 généré): 0.0
# 	Temps de traitement pour 792 : 5.739056587219238
# 	Temps d'extraction de features pour 792 : 1.1528429985046387
# 	Temps de prédiction pour 792 : 3.244894504547119
# 	Fenêtres gardées : 0 sur 792 (p>=0.5)
# 	Meilleur score de l'itération : 0.10936971911186838 pour [[ 700  595]
#  [1354 1370]]
# 	Temps cumulé : 474.4457929134369
#
# 	Itération 39 : h=0871 | w=0735
# 	Temps sliding_window x2 (640 généré): 0.0
# 	Temps de traitement pour 640 : 6.45943284034729
# 	Temps d'extraction de features pour 640 : 0.9613597393035889
# 	Temps de prédiction pour 640 : 2.6757493019104004
# 	Fenêtres gardées : 0 sur 640 (p>=0.5)
# 	Meilleur score de l'itération : 0.08151753065811834 pour [[ 315    0]
#  [1186  735]]
# 	Temps cumulé : 484.54233479499817
#
# 	Itération 40 : h=0967 | w=0816
# 	Temps sliding_window x2 (442 généré): 0.0
# 	Temps de traitement pour 442 : 6.094867944717407
# 	Temps d'extraction de features pour 442 : 0.6677844524383545
# 	Temps de prédiction pour 442 : 1.8404572010040283
# 	Fenêtres gardées : 0 sur 442 (p>=0.5)
# 	Meilleur score de l'itération : 0.10837286763603794 pour [[  0   0]
#  [967 816]]
# 	Temps cumulé : 493.14550614356995
#
# 	Itération 41 : h=0107 | w=0105
# 	Temps sliding_window x2 (2812 généré): 0.0030531883239746094
# 	Temps de traitement pour 2812 : 0.6005425453186035
# 	Temps d'extraction de features pour 2812 : 4.320326566696167
# 	Temps de prédiction pour 2812 : 11.681841850280762
# 	Fenêtres gardées : 5 sur 2812 (p>=0.5)
# 	Meilleur score de l'itération : 0.7306151935988218 pour [[595 840]
#  [702 945]]
# 	Temps cumulé : 509.75127029418945
#
# 	Itération 42 : h=0202 | w=0198
# 	Temps sliding_window x2 (2450 généré): 0.0
# 	Temps de traitement pour 2450 : 0.9729435443878174
# 	Temps d'extraction de features pour 2450 : 3.7430460453033447
# 	Temps de prédiction pour 2450 : 10.082139730453491
# 	Fenêtres gardées : 4 sur 2450 (p>=0.5)
# 	Meilleur score de l'itération : 0.9112592799927194 pour [[140 630]
#  [342 828]]
# 	Temps cumulé : 524.5493996143341
#
# 	Itération 43 : h=0298 | w=0293
# 	Temps sliding_window x2 (2048 généré): 0.0
# 	Temps de traitement pour 2048 : 1.5204746723175049
# 	Temps d'extraction de features pour 2048 : 3.1393699645996094
# 	Temps de prédiction pour 2048 : 8.418952703475952
# 	Fenêtres gardées : 4 sur 2048 (p>=0.5)
# 	Meilleur score de l'itération : 0.9097426732565568 pour [[315 140]
#  [608 438]]
# 	Temps cumulé : 537.6281969547272
#
# 	Itération 44 : h=0393 | w=0386
# 	Temps sliding_window x2 (1682 généré): 0.0019943714141845703
# 	Temps de traitement pour 1682 : 2.864982843399048
# 	Temps d'extraction de features pour 1682 : 2.5331685543060303
# 	Temps de prédiction pour 1682 : 7.051359176635742
# 	Fenêtres gardées : 1 sur 1682 (p>=0.5)
# 	Meilleur score de l'itération : 0.7501421513815838 pour [[   0  875]
#  [ 386 1268]]
# 	Temps cumulé : 550.0807251930237
#
# 	Itération 45 : h=0489 | w=0480
# 	Temps sliding_window x2 (1458 généré): 0.0009989738464355469
# 	Temps de traitement pour 1458 : 4.242902755737305
# 	Temps d'extraction de features pour 1458 : 2.282968282699585
# 	Temps de prédiction pour 1458 : 6.06210994720459
# 	Fenêtres gardées : 2 sur 1458 (p>=0.5)
# 	Meilleur score de l'itération : 0.5 pour [[245  70]
#  [734 550]]
# 	Temps cumulé : 562.6697051525116
#
# 	Itération 46 : h=0584 | w=0574
# 	Temps sliding_window x2 (1152 généré): 0.0008254051208496094
# 	Temps de traitement pour 1152 : 4.938795804977417
# 	Temps d'extraction de features pour 1152 : 1.7580854892730713
# 	Temps de prédiction pour 1152 : 4.766135215759277
# 	Fenêtres gardées : 0 sur 1152 (p>=0.5)
# 	Meilleur score de l'itération : 0.3766955896436637 pour [[ 805   35]
#  [1379  619]]
# 	Temps cumulé : 574.1347901821136
#
# 	Itération 47 : h=0680 | w=0668
# 	Temps sliding_window x2 (882 généré): 0.0010790824890136719
# 	Temps de traitement pour 882 : 5.627369165420532
# 	Temps d'extraction de features pour 882 : 1.3328242301940918
# 	Temps de prédiction pour 882 : 3.6455740928649902
# 	Fenêtres gardées : 0 sur 882 (p>=0.5)
# 	Meilleur score de l'itération : 0.23903212806611662 pour [[ 70   0]
#  [750 668]]
# 	Temps cumulé : 584.7416367530823
#
# 	Itération 48 : h=0775 | w=0761
# 	Temps sliding_window x2 (684 généré): 0.0010631084442138672
# 	Temps de traitement pour 684 : 6.219029188156128
# 	Temps d'extraction de features pour 684 : 1.0455217361450195
# 	Temps de prédiction pour 684 : 2.819044351577759
# 	Fenêtres gardées : 0 sur 684 (p>=0.5)
# 	Meilleur score de l'itération : 0.08375963557328642 pour [[  0   0]
#  [775 761]]
# 	Temps cumulé : 594.8262951374054
#
# 	Itération 49 : h=0871 | w=0856
# 	Temps sliding_window x2 (512 généré): 0.0009937286376953125
# 	Temps de traitement pour 512 : 6.3204264640808105
# 	Temps d'extraction de features pour 512 : 0.76853346824646
# 	Temps de prédiction pour 512 : 2.14380145072937
# 	Fenêtres gardées : 0 sur 512 (p>=0.5)
# 	Meilleur score de l'itération : 0.048875401374867226 pour [[  0   0]
#  [871 856]]
# 	Temps cumulé : 604.0600502490997
#
# 	Itération 50 : h=0967 | w=0950
# 	Temps sliding_window x2 (338 généré): 0.0010809898376464844
# 	Temps de traitement pour 338 : 5.424008846282959
# 	Temps d'extraction de features pour 338 : 0.5214362144470215
# 	Temps de prédiction pour 338 : 1.4174728393554688
# 	Fenêtres gardées : 0 sur 338 (p>=0.5)
# 	Meilleur score de l'itération : 0.07678211737757466 pour [[  0   0]
#  [967 950]]
# 	Temps cumulé : 611.4253191947937
#
# Temps total de détection : 611.4255478382111
#
# ---------Traitement de l'image 0001---------
#
# Temps setup : 0.0
# Nombre d'itérations : 50
#
# 	Itération 1 : h=0107 | w=0045
# 	Temps sliding_window x2 (1898 généré): 0.0018911361694335938
# 	Temps de traitement pour 1898 : 0.3753011226654053
# 	Temps d'extraction de features pour 1898 : 2.9041666984558105
# 	Temps de prédiction pour 1898 : 7.927826881408691
# 	Fenêtres gardées : 0 sur 1898 (p>=0.5)
# 	Meilleur score de l'itération : 0.3685645828418652 pour [[ 175 1225]
#  [ 220 1332]]
# 	Temps cumulé : 11.20918583869934
#
# 	Itération 2 : h=0202 | w=0086
# 	Temps sliding_window x2 (1673 généré): 0.00512385368347168
# 	Temps de traitement pour 1673 : 0.45594143867492676
# 	Temps d'extraction de features pour 1673 : 2.6654295921325684
# 	Temps de prédiction pour 1673 : 6.886822938919067
# 	Fenêtres gardées : 1 sur 1673 (p>=0.5)
# 	Meilleur score de l'itération : 0.6558130865444407 pour [[ 175 1225]
#  [ 377 1311]]
# 	Temps cumulé : 21.222503662109375
#
# 	Itération 3 : h=0298 | w=0127
# 	Temps sliding_window x2 (1471 généré): 0.0
# 	Temps de traitement pour 1471 : 0.5807886123657227
# 	Temps d'extraction de features pour 1471 : 2.26155948638916
# 	Temps de prédiction pour 1471 : 6.066693305969238
# 	Fenêtres gardées : 1 sur 1471 (p>=0.5)
# 	Meilleur score de l'itération : 0.8582105679725638 pour [[ 420  875]
#  [ 718 1002]]
# 	Temps cumulé : 30.131545066833496
#
# 	Itération 4 : h=0393 | w=0168
# 	Temps sliding_window x2 (1214 généré): 0.001027822494506836
# 	Temps de traitement pour 1214 : 0.6427843570709229
# 	Temps d'extraction de features pour 1214 : 1.796673059463501
# 	Temps de prédiction pour 1214 : 4.969747304916382
# 	Fenêtres gardées : 5 sur 1214 (p>=0.5)
# 	Meilleur score de l'itération : 0.679048464956697 pour [[ 490  980]
#  [ 883 1148]]
# 	Temps cumulé : 37.54277443885803
#
# 	Itération 5 : h=0489 | w=0209
# 	Temps sliding_window x2 (1022 généré): 0.008548498153686523
# 	Temps de traitement pour 1022 : 0.8914985656738281
# 	Temps d'extraction de features pour 1022 : 1.5580506324768066
# 	Temps de prédiction pour 1022 : 4.160374641418457
# 	Fenêtres gardées : 5 sur 1022 (p>=0.5)
# 	Meilleur score de l'itération : 0.7250381590085271 pour [[ 455  700]
#  [ 664 1189]]
# 	Temps cumulé : 44.16124677658081
#
# 	Itération 6 : h=0584 | w=0249
# 	Temps sliding_window x2 (810 généré): 0.0009920597076416016
# 	Temps de traitement pour 810 : 1.1988167762756348
# 	Temps d'extraction de features pour 810 : 1.1389358043670654
# 	Temps de prédiction pour 810 : 3.3663229942321777
# 	Fenêtres gardées : 6 sur 810 (p>=0.5)
# 	Meilleur score de l'itération : 0.9744410670636903 pour [[105 630]
#  [689 879]]
# 	Temps cumulé : 49.86631441116333
#
# 	Itération 7 : h=0680 | w=0290
# 	Temps sliding_window x2 (655 généré): 0.0
# 	Temps de traitement pour 655 : 1.474919080734253
# 	Temps d'extraction de features pour 655 : 0.9375720024108887
# 	Temps de prédiction pour 655 : 2.7173640727996826
# 	Fenêtres gardées : 6 sur 655 (p>=0.5)
# 	Meilleur score de l'itération : 0.9862599672592127 pour [[  70  770]
#  [ 750 1060]]
# 	Temps cumulé : 54.99818158149719
#
# 	Itération 8 : h=0775 | w=0331
# 	Temps sliding_window x2 (479 généré): 0.0
# 	Temps de traitement pour 479 : 1.4215445518493652
# 	Temps d'extraction de features pour 479 : 0.6834602355957031
# 	Temps de prédiction pour 479 : 1.9967217445373535
# 	Fenêtres gardées : 4 sur 479 (p>=0.5)
# 	Meilleur score de l'itération : 0.7519979287926116 pour [[ 385  420]
#  [ 716 1195]]
# 	Temps cumulé : 59.099908113479614
#
# 	Itération 9 : h=0871 | w=0372
# 	Temps sliding_window x2 (332 généré): 0.0
# 	Temps de traitement pour 332 : 1.226172924041748
# 	Temps d'extraction de features pour 332 : 0.455580472946167
# 	Temps de prédiction pour 332 : 1.3915269374847412
# 	Fenêtres gardées : 3 sur 332 (p>=0.5)
# 	Meilleur score de l'itération : 0.7044968533718097 pour [[ 385  350]
#  [ 757 1221]]
# 	Temps cumulé : 62.17318844795227
#
# 	Itération 10 : h=0967 | w=0413
# 	Temps sliding_window x2 (195 généré): 0.0
# 	Temps de traitement pour 195 : 1.0444772243499756
# 	Temps d'extraction de features pour 195 : 0.284318208694458
# 	Temps de prédiction pour 195 : 0.820732593536377
# 	Fenêtres gardées : 1 sur 195 (p>=0.5)
# 	Meilleur score de l'itération : 0.6219025787458687 pour [[ 385  385]
#  [ 798 1352]]
# 	Temps cumulé : 64.32271647453308
#
# 	Itération 11 : h=0107 | w=0060
# 	Temps sliding_window x2 (1861 généré): 0.0
# 	Temps de traitement pour 1861 : 0.35829734802246094
# 	Temps d'extraction de features pour 1861 : 2.764035940170288
# 	Temps de prédiction pour 1861 : 7.790101051330566
# 	Fenêtres gardées : 1 sur 1861 (p>=0.5)
# 	Meilleur score de l'itération : 0.7589515144188281 pour [[ 175 1225]
#  [ 235 1332]]
# 	Temps cumulé : 75.2351508140564
#
# 	Itération 12 : h=0202 | w=0114
# 	Temps sliding_window x2 (1617 généré): 0.0019996166229248047
# 	Temps de traitement pour 1617 : 0.4633674621582031
# 	Temps d'extraction de features pour 1617 : 2.3664300441741943
# 	Temps de prédiction pour 1617 : 6.566996812820435
# 	Fenêtres gardées : 6 sur 1617 (p>=0.5)
# 	Meilleur score de l'itération : 0.933562749424195 pour [[ 490 1015]
#  [ 692 1129]]
# 	Temps cumulé : 84.63394474983215
#
# 	Itération 13 : h=0298 | w=0168
# 	Temps sliding_window x2 (1388 généré): 0.001001119613647461
# 	Temps de traitement pour 1388 : 0.595259428024292
# 	Temps d'extraction de features pour 1388 : 2.010392665863037
# 	Temps de prédiction pour 1388 : 5.662351608276367
# 	Fenêtres gardées : 11 sur 1388 (p>=0.5)
# 	Meilleur score de l'itération : 0.9395360416313334 pour [[ 420  840]
#  [ 718 1008]]
# 	Temps cumulé : 92.9029495716095
#
# 	Itération 14 : h=0393 | w=0222
# 	Temps sliding_window x2 (1153 généré): 0.0
# 	Temps de traitement pour 1153 : 0.7956109046936035
# 	Temps d'extraction de features pour 1153 : 1.664201259613037
# 	Temps de prédiction pour 1153 : 4.710695028305054
# 	Fenêtres gardées : 14 sur 1153 (p>=0.5)
# 	Meilleur score de l'itération : 0.9610518971228932 pour [[420 665]
#  [813 887]]
# 	Temps cumulé : 100.07345676422119
#
# 	Itération 15 : h=0489 | w=0277
# 	Temps sliding_window x2 (942 généré): 0.0010623931884765625
# 	Temps de traitement pour 942 : 1.390491247177124
# 	Temps d'extraction de features pour 942 : 1.3330726623535156
# 	Temps de prédiction pour 942 : 3.8777365684509277
# 	Fenêtres gardées : 13 sur 942 (p>=0.5)
# 	Meilleur score de l'itération : 0.9646362903673146 pour [[420 385]
#  [697 874]]
# 	Temps cumulé : 106.67581963539124
#
# 	Itération 16 : h=0584 | w=0330
# 	Temps sliding_window x2 (742 généré): 0.0
# 	Temps de traitement pour 742 : 1.566422462463379
# 	Temps d'extraction de features pour 742 : 1.11635422706604
# 	Temps de prédiction pour 742 : 3.0801477432250977
# 	Fenêtres gardées : 14 sur 742 (p>=0.5)
# 	Meilleur score de l'itération : 0.9674434650441829 pour [[ 385  420]
#  [ 715 1004]]
# 	Temps cumulé : 112.43987774848938
#
# 	Itération 17 : h=0680 | w=0385
# 	Temps sliding_window x2 (576 généré): 0.0
# 	Temps de traitement pour 576 : 1.8012750148773193
# 	Temps d'extraction de features pour 576 : 0.8417677879333496
# 	Temps de prédiction pour 576 : 2.414858818054199
# 	Fenêtres gardées : 12 sur 576 (p>=0.5)
# 	Meilleur score de l'itération : 0.9877824344827262 pour [[  70  700]
#  [ 750 1085]]
# 	Temps cumulé : 117.49777936935425
#
# 	Itération 18 : h=0775 | w=0439
# 	Temps sliding_window x2 (410 généré): 0.0009951591491699219
# 	Temps de traitement pour 410 : 1.7337968349456787
# 	Temps d'extraction de features pour 410 : 0.5870678424835205
# 	Temps de prédiction pour 410 : 1.716749668121338
# 	Fenêtres gardées : 8 sur 410 (p>=0.5)
# 	Meilleur score de l'itération : 0.9059103948335478 pour [[  70  595]
#  [ 845 1034]]
# 	Temps cumulé : 121.53739142417908
#
# 	Itération 19 : h=0871 | w=0493
# 	Temps sliding_window x2 (260 généré): 0.0
# 	Temps de traitement pour 260 : 1.5653376579284668
# 	Temps d'extraction de features pour 260 : 0.3712794780731201
# 	Temps de prédiction pour 260 : 1.0653142929077148
# 	Fenêtres gardées : 0 sur 260 (p>=0.5)
# 	Meilleur score de l'itération : 0.4464283222767043 pour [[ 350  350]
#  [ 843 1221]]
# 	Temps cumulé : 124.53994941711426
#
# 	Itération 20 : h=0967 | w=0547
# 	Temps sliding_window x2 (156 généré): 0.0
# 	Temps de traitement pour 156 : 1.19944429397583
# 	Temps d'extraction de features pour 156 : 0.2221825122833252
# 	Temps de prédiction pour 156 : 0.6402366161346436
# 	Fenêtres gardées : 0 sur 156 (p>=0.5)
# 	Meilleur score de l'itération : 0.2810528633088853 pour [[ 280  385]
#  [ 827 1352]]
# 	Temps cumulé : 126.60209965705872
#
# 	Itération 21 : h=0107 | w=0075
# 	Temps sliding_window x2 (1837 généré): 0.0
# 	Temps de traitement pour 1837 : 0.39186596870422363
# 	Temps d'extraction de features pour 1837 : 2.7851059436798096
# 	Temps de prédiction pour 1837 : 7.542544841766357
# 	Fenêtres gardées : 3 sur 1837 (p>=0.5)
# 	Meilleur score de l'itération : 0.9005560389078984 pour [[ 175 1225]
#  [ 250 1332]]
# 	Temps cumulé : 137.3216164112091
#
# 	Itération 22 : h=0202 | w=0142
# 	Temps sliding_window x2 (1561 généré): 0.0
# 	Temps de traitement pour 1561 : 0.5124404430389404
# 	Temps d'extraction de features pour 1561 : 2.287032127380371
# 	Temps de prédiction pour 1561 : 6.386738300323486
# 	Fenêtres gardées : 11 sur 1561 (p>=0.5)
# 	Meilleur score de l'itération : 0.9895842867505587 pour [[420 700]
#  [622 842]]
# 	Temps cumulé : 146.5204360485077
#
# 	Itération 23 : h=0298 | w=0210
# 	Temps sliding_window x2 (1337 généré): 0.0
# 	Temps de traitement pour 1337 : 0.721433162689209
# 	Temps d'extraction de features pour 1337 : 1.9938721656799316
# 	Temps de prédiction pour 1337 : 5.475574016571045
# 	Fenêtres gardées : 23 sur 1337 (p>=0.5)
# 	Meilleur score de l'itération : 0.9914220133150647 pour [[385 665]
#  [683 875]]
# 	Temps cumulé : 154.71131539344788
#
# 	Itération 24 : h=0393 | w=0277
# 	Temps sliding_window x2 (1079 généré): 0.00410914421081543
# 	Temps de traitement pour 1079 : 0.9662926197052002
# 	Temps d'extraction de features pour 1079 : 1.5751566886901855
# 	Temps de prédiction pour 1079 : 4.424105167388916
# 	Fenêtres gardées : 18 sur 1079 (p>=0.5)
# 	Meilleur score de l'itération : 0.9916932888691242 pour [[420 630]
#  [813 907]]
# 	Temps cumulé : 161.680979013443
#
# 	Itération 25 : h=0489 | w=0344
# 	Temps sliding_window x2 (862 généré): 0.0
# 	Temps de traitement pour 862 : 1.4295673370361328
# 	Temps d'extraction de features pour 862 : 1.2399823665618896
# 	Temps de prédiction pour 862 : 3.572441816329956
# 	Fenêtres gardées : 9 sur 862 (p>=0.5)
# 	Meilleur score de l'itération : 0.8991902092997534 pour [[385 490]
#  [729 979]]
# 	Temps cumulé : 167.92297053337097
#
# 	Itération 26 : h=0584 | w=0411
# 	Temps sliding_window x2 (650 généré): 0.0
# 	Temps de traitement pour 650 : 1.794734001159668
# 	Temps d'extraction de features pour 650 : 0.9245491027832031
# 	Temps de prédiction pour 650 : 2.6996402740478516
# 	Fenêtres gardées : 11 sur 650 (p>=0.5)
# 	Meilleur score de l'itération : 0.9833971687371692 pour [[  70  700]
#  [ 654 1111]]
# 	Temps cumulé : 173.35460090637207
#
# 	Itération 27 : h=0680 | w=0479
# 	Temps sliding_window x2 (489 généré): 0.0003376007080078125
# 	Temps de traitement pour 489 : 1.9866256713867188
# 	Temps d'extraction de features pour 489 : 0.6999351978302002
# 	Temps de prédiction pour 489 : 2.0218262672424316
# 	Fenêtres gardées : 11 sur 489 (p>=0.5)
# 	Meilleur score de l'itération : 0.9853366023279798 pour [[  70  630]
#  [ 750 1109]]
# 	Temps cumulé : 178.06431484222412
#
# 	Itération 28 : h=0775 | w=0546
# 	Temps sliding_window x2 (341 généré): 0.0
# 	Temps de traitement pour 341 : 1.9687204360961914
# 	Temps d'extraction de features pour 341 : 0.501009464263916
# 	Temps de prédiction pour 341 : 1.4042155742645264
# 	Fenêtres gardées : 3 sur 341 (p>=0.5)
# 	Meilleur score de l'itération : 0.8670752959182458 pour [[  70  560]
#  [ 845 1106]]
# 	Temps cumulé : 181.93826031684875
#
# 	Itération 29 : h=0871 | w=0614
# 	Temps sliding_window x2 (206 généré): 0.0
# 	Temps de traitement pour 206 : 1.6022706031799316
# 	Temps d'extraction de features pour 206 : 0.29596710205078125
# 	Temps de prédiction pour 206 : 0.8452343940734863
# 	Fenêtres gardées : 0 sur 206 (p>=0.5)
# 	Meilleur score de l'itération : 0.15052496127839327 pour [[ 280  490]
#  [ 894 1361]]
# 	Temps cumulé : 184.68203592300415
#
# 	Itération 30 : h=0967 | w=0682
# 	Temps sliding_window x2 (104 généré): 0.0
# 	Temps de traitement pour 104 : 1.0416581630706787
# 	Temps d'extraction de features pour 104 : 0.15635895729064941
# 	Temps de prédiction pour 104 : 0.4362337589263916
# 	Fenêtres gardées : 0 sur 104 (p>=0.5)
# 	Meilleur score de l'itération : 0.14883113245424476 pour [[ 245   35]
#  [ 927 1002]]
# 	Temps cumulé : 186.31727838516235
#
# 	Itération 31 : h=0107 | w=0090
# 	Temps sliding_window x2 (1837 généré): 0.0009963512420654297
# 	Temps de traitement pour 1837 : 0.39265942573547363
# 	Temps d'extraction de features pour 1837 : 2.7936973571777344
# 	Temps de prédiction pour 1837 : 7.596675634384155
# 	Fenêtres gardées : 6 sur 1837 (p>=0.5)
# 	Meilleur score de l'itération : 0.8610944171859368 pour [[ 175 1225]
#  [ 265 1332]]
# 	Temps cumulé : 197.10130715370178
#
# 	Itération 32 : h=0202 | w=0170
# 	Temps sliding_window x2 (1526 généré): 0.0
# 	Temps de traitement pour 1526 : 0.5544493198394775
# 	Temps d'extraction de features pour 1526 : 2.270738363265991
# 	Temps de prédiction pour 1526 : 6.2676308155059814
# 	Fenêtres gardées : 18 sur 1526 (p>=0.5)
# 	Meilleur score de l'itération : 0.9965888761984686 pour [[420 700]
#  [622 870]]
# 	Temps cumulé : 206.19412565231323
#
# 	Itération 33 : h=0298 | w=0251
# 	Temps sliding_window x2 (1267 généré): 0.0022401809692382812
# 	Temps de traitement pour 1267 : 0.8037424087524414
# 	Temps d'extraction de features pour 1267 : 1.8780550956726074
# 	Temps de prédiction pour 1267 : 5.1876819133758545
# 	Fenêtres gardées : 29 sur 1267 (p>=0.5)
# 	Meilleur score de l'itération : 0.9972557770199816 pour [[420 630]
#  [671 928]]
# 	Temps cumulé : 214.06584525108337
#
# 	Itération 34 : h=0393 | w=0331
# 	Temps sliding_window x2 (1018 généré): 0.0
# 	Temps de traitement pour 1018 : 1.1539673805236816
# 	Temps d'extraction de features pour 1018 : 1.520615816116333
# 	Temps de prédiction pour 1018 : 4.182762861251831
# 	Fenêtres gardées : 23 sur 1018 (p>=0.5)
# 	Meilleur score de l'itération : 0.9821902834448608 pour [[385 560]
#  [716 953]]
# 	Temps cumulé : 220.92319130897522
#
# 	Itération 35 : h=0489 | w=0412
# 	Temps sliding_window x2 (782 généré): 0.0
# 	Temps de traitement pour 782 : 1.6991667747497559
# 	Temps d'extraction de features pour 782 : 1.1546471118927002
# 	Temps de prédiction pour 782 : 3.2373616695404053
# 	Fenêtres gardées : 12 sur 782 (p>=0.5)
# 	Meilleur score de l'itération : 0.8857891705493469 pour [[420 245]
#  [909 657]]
# 	Temps cumulé : 227.01544785499573
#
# 	Itération 36 : h=0584 | w=0493
# 	Temps sliding_window x2 (572 généré): 0.0
# 	Temps de traitement pour 572 : 1.9407105445861816
# 	Temps d'extraction de features pour 572 : 0.8200666904449463
# 	Temps de prédiction pour 572 : 2.368443489074707
# 	Fenêtres gardées : 8 sur 572 (p>=0.5)
# 	Meilleur score de l'itération : 0.9934587615611131 pour [[  70  665]
#  [ 654 1158]]
# 	Temps cumulé : 232.14466857910156
#
# 	Itération 37 : h=0680 | w=0574
# 	Temps sliding_window x2 (423 généré): 0.0
# 	Temps de traitement pour 423 : 2.2895638942718506
# 	Temps d'extraction de features pour 423 : 0.6052212715148926
# 	Temps de prédiction pour 423 : 1.739011526107788
# 	Fenêtres gardées : 10 sur 423 (p>=0.5)
# 	Meilleur score de l'itération : 0.9774617792702142 pour [[  70  595]
#  [ 750 1169]]
# 	Temps cumulé : 236.77946639060974
#
# 	Itération 38 : h=0775 | w=0654
# 	Temps sliding_window x2 (254 généré): 0.0
# 	Temps de traitement pour 254 : 1.841444969177246
# 	Temps d'extraction de features pour 254 : 0.37709712982177734
# 	Temps de prédiction pour 254 : 1.0435385704040527
# 	Fenêtres gardées : 4 sur 254 (p>=0.5)
# 	Meilleur score de l'itération : 0.8096414410499597 pour [[  70  595]
#  [ 845 1249]]
# 	Temps cumulé : 240.04154706001282
#
# 	Itération 39 : h=0871 | w=0735
# 	Temps sliding_window x2 (136 généré): 0.0
# 	Temps de traitement pour 136 : 1.421959400177002
# 	Temps d'extraction de features pour 136 : 0.19763517379760742
# 	Temps de prédiction pour 136 : 0.5592761039733887
# 	Fenêtres gardées : 1 sur 136 (p>=0.5)
# 	Meilleur score de l'itération : 0.5268604726405697 pour [[  70  315]
#  [ 805 1186]]
# 	Temps cumulé : 242.22041773796082
#
# 	Itération 40 : h=0967 | w=0816
# 	Temps sliding_window x2 (52 généré): 0.0
# 	Temps de traitement pour 52 : 0.7190115451812744
# 	Temps d'extraction de features pour 52 : 0.07909011840820312
# 	Temps de prédiction pour 52 : 0.21874642372131348
# 	Fenêtres gardées : 0 sur 52 (p>=0.5)
# 	Meilleur score de l'itération : 0.4758467537643388 pour [[   0  210]
#  [ 816 1177]]
# 	Temps cumulé : 243.2372658252716
#
# 	Itération 41 : h=0107 | w=0105
# 	Temps sliding_window x2 (1800 généré): 0.0020720958709716797
# 	Temps de traitement pour 1800 : 0.38089799880981445
# 	Temps d'extraction de features pour 1800 : 2.7454330921173096
# 	Temps de prédiction pour 1800 : 7.451334714889526
# 	Fenêtres gardées : 10 sur 1800 (p>=0.5)
# 	Meilleur score de l'itération : 0.9522548285957062 pour [[ 455 1225]
#  [ 562 1330]]
# 	Temps cumulé : 253.81700372695923
#
# 	Itération 42 : h=0202 | w=0198
# 	Temps sliding_window x2 (1505 généré): 0.001905679702758789
# 	Temps de traitement pour 1505 : 0.5853714942932129
# 	Temps d'extraction de features pour 1505 : 2.2627620697021484
# 	Temps de prédiction pour 1505 : 6.17459511756897
# 	Fenêtres gardées : 25 sur 1505 (p>=0.5)
# 	Meilleur score de l'itération : 0.9899726901398976 pour [[ 455  980]
#  [ 653 1182]]
# 	Temps cumulé : 262.8425884246826
#
# 	Itération 43 : h=0298 | w=0293
# 	Temps sliding_window x2 (1216 généré): 0.0
# 	Temps de traitement pour 1216 : 0.8709747791290283
# 	Temps d'extraction de features pour 1216 : 1.8078773021697998
# 	Temps de prédiction pour 1216 : 4.9933576583862305
# 	Fenêtres gardées : 25 sur 1216 (p>=0.5)
# 	Meilleur score de l'itération : 0.9968334277943183 pour [[420 630]
#  [713 928]]
# 	Temps cumulé : 270.51573300361633
#
# 	Itération 44 : h=0393 | w=0386
# 	Temps sliding_window x2 (928 généré): 0.0011126995086669922
# 	Temps de traitement pour 928 : 1.4829726219177246
# 	Temps d'extraction de features pour 928 : 1.3639640808105469
# 	Temps de prédiction pour 928 : 3.81807017326355
# 	Fenêtres gardées : 21 sur 928 (p>=0.5)
# 	Meilleur score de l'itération : 0.9756674417348629 pour [[385 280]
#  [778 666]]
# 	Temps cumulé : 277.1824631690979
#
# 	Itération 45 : h=0489 | w=0480
# 	Temps sliding_window x2 (702 généré): 0.0
# 	Temps de traitement pour 702 : 1.9502809047698975
# 	Temps d'extraction de features pour 702 : 1.0204737186431885
# 	Temps de prédiction pour 702 : 2.882765054702759
# 	Fenêtres gardées : 4 sur 702 (p>=0.5)
# 	Meilleur score de l'itération : 0.9379153505543395 pour [[  70  630]
#  [ 559 1110]]
# 	Temps cumulé : 283.03598284721375
#
# 	Itération 46 : h=0584 | w=0574
# 	Temps sliding_window x2 (504 généré): 0.0004558563232421875
# 	Temps de traitement pour 504 : 2.1420493125915527
# 	Temps d'extraction de features pour 504 : 0.7612338066101074
# 	Temps de prédiction pour 504 : 2.112229108810425
# 	Fenêtres gardées : 7 sur 504 (p>=0.5)
# 	Meilleur score de l'itération : 0.9945684539920043 pour [[  70  595]
#  [ 654 1169]]
# 	Temps cumulé : 288.0524287223816
#
# 	Itération 47 : h=0680 | w=0668
# 	Temps sliding_window x2 (336 généré): 0.0
# 	Temps de traitement pour 336 : 2.245392322540283
# 	Temps d'extraction de features pour 336 : 0.5134236812591553
# 	Temps de prédiction pour 336 : 1.390108346939087
# 	Fenêtres gardées : 8 sur 336 (p>=0.5)
# 	Meilleur score de l'itération : 0.9520829291293736 pour [[  70  560]
#  [ 750 1228]]
# 	Temps cumulé : 292.2013530731201
#
# 	Itération 48 : h=0775 | w=0761
# 	Temps sliding_window x2 (185 généré): 0.0
# 	Temps de traitement pour 185 : 1.6545372009277344
# 	Temps d'extraction de features pour 185 : 0.2660181522369385
# 	Temps de prédiction pour 185 : 0.7773833274841309
# 	Fenêtres gardées : 10 sur 185 (p>=0.5)
# 	Meilleur score de l'itération : 0.6941903400983286 pour [[  70  280]
#  [ 845 1041]]
# 	Temps cumulé : 294.8992917537689
#
# 	Itération 49 : h=0871 | w=0856
# 	Temps sliding_window x2 (80 généré): 0.0
# 	Temps de traitement pour 80 : 1.0099272727966309
# 	Temps d'extraction de features pour 80 : 0.11252093315124512
# 	Temps de prédiction pour 80 : 0.3388235569000244
# 	Fenêtres gardées : 5 sur 80 (p>=0.5)
# 	Meilleur score de l'itération : 0.7910737879696672 pour [[   0  315]
#  [ 856 1186]]
# 	Temps cumulé : 296.3731265068054
#
# 	Itération 50 : h=0967 | w=0950
# 	Temps sliding_window x2 (0 généré): 0.0
# 	Abandon de l'itération
#
# Temps total de détection : 296.3731265068054
#
# ---------Traitement de l'image 0002---------
#
# Temps setup : 0.0
# Nombre d'itérations : 50
#
# 	Itération 1 : h=0107 | w=0045
# 	Temps sliding_window x2 (2126 généré): 0.0019593238830566406
# 	Temps de traitement pour 2126 : 0.4001486301422119
# 	Temps d'extraction de features pour 2126 : 3.1408307552337646
# 	Temps de prédiction pour 2126 : 8.865407228469849
# 	Fenêtres gardées : 3 sur 2126 (p>=0.5)
# 	Meilleur score de l'itération : 0.7778426575294738 pour [[805 560]
#  [912 605]]
# 	Temps cumulé : 12.408345937728882
#
# 	Itération 2 : h=0202 | w=0086
# 	Temps sliding_window x2 (1930 généré): 0.0
# 	Temps de traitement pour 1930 : 0.5314769744873047
# 	Temps d'extraction de features pour 1930 : 2.9036777019500732
# 	Temps de prédiction pour 1930 : 7.9842705726623535
# 	Fenêtres gardées : 2 sur 1930 (p>=0.5)
# 	Meilleur score de l'itération : 0.9862245843680162 pour [[455 490]
#  [657 576]]
# 	Temps cumulé : 23.827771186828613
#
# 	Itération 3 : h=0298 | w=0127
# 	Temps sliding_window x2 (1678 généré): 0.0
# 	Temps de traitement pour 1678 : 0.6605961322784424
# 	Temps d'extraction de features pour 1678 : 2.504601240158081
# 	Temps de prédiction pour 1678 : 6.911632776260376
# 	Fenêtres gardées : 6 sur 1678 (p>=0.5)
# 	Meilleur score de l'itération : 0.92450028620382 pour [[175 420]
#  [302 718]]
# 	Temps cumulé : 33.90559959411621
#
# 	Itération 4 : h=0393 | w=0168
# 	Temps sliding_window x2 (1438 généré): 0.0
# 	Temps de traitement pour 1438 : 0.8208153247833252
# 	Temps d'extraction de features pour 1438 : 2.1414144039154053
# 	Temps de prédiction pour 1438 : 5.920360565185547
# 	Fenêtres gardées : 1 sur 1438 (p>=0.5)
# 	Meilleur score de l'itération : 0.606061133056188 pour [[455 490]
#  [848 658]]
# 	Temps cumulé : 42.78919005393982
#
# 	Itération 5 : h=0489 | w=0209
# 	Temps sliding_window x2 (1270 généré): 0.0010535717010498047
# 	Temps de traitement pour 1270 : 1.08935546875
# 	Temps d'extraction de features pour 1270 : 1.913778305053711
# 	Temps de prédiction pour 1270 : 5.2438437938690186
# 	Fenêtres gardées : 3 sur 1270 (p>=0.5)
# 	Meilleur score de l'itération : 0.7003296586757151 pour [[   0  805]
#  [ 489 1014]]
# 	Temps cumulé : 51.04075646400452
#
# 	Itération 6 : h=0584 | w=0249
# 	Temps sliding_window x2 (1014 généré): 0.0012369155883789062
# 	Temps de traitement pour 1014 : 1.5050334930419922
# 	Temps d'extraction de features pour 1014 : 1.5465257167816162
# 	Temps de prédiction pour 1014 : 4.254458904266357
# 	Fenêtres gardées : 1 sur 1014 (p>=0.5)
# 	Meilleur score de l'itération : 0.5735848159711711 pour [[245 175]
#  [494 759]]
# 	Temps cumulé : 58.34827423095703
#
# 	Itération 7 : h=0680 | w=0290
# 	Temps sliding_window x2 (814 généré): 0.0
# 	Temps de traitement pour 814 : 1.7580459117889404
# 	Temps d'extraction de features pour 814 : 1.1992905139923096
# 	Temps de prédiction pour 814 : 3.3994569778442383
# 	Fenêtres gardées : 0 sur 814 (p>=0.5)
# 	Meilleur score de l'itération : 0.16980861813273324 pour [[525 105]
#  [815 785]]
# 	Temps cumulé : 64.70568442344666
#
# 	Itération 8 : h=0775 | w=0331
# 	Temps sliding_window x2 (626 généré): 0.01300501823425293
# 	Temps de traitement pour 626 : 1.8449459075927734
# 	Temps d'extraction de features pour 626 : 0.9457147121429443
# 	Temps de prédiction pour 626 : 2.625257730484009
# 	Fenêtres gardées : 0 sur 626 (p>=0.5)
# 	Meilleur score de l'itération : 0.3551663441392949 pour [[ 595  315]
#  [1370  646]]
# 	Temps cumulé : 70.13474988937378
#
# 	Itération 9 : h=0871 | w=0372
# 	Temps sliding_window x2 (500 généré): 0.0015077590942382812
# 	Temps de traitement pour 500 : 1.8311140537261963
# 	Temps d'extraction de features pour 500 : 0.7563722133636475
# 	Temps de prédiction pour 500 : 2.076613664627075
# 	Fenêtres gardées : 0 sur 500 (p>=0.5)
# 	Meilleur score de l'itération : 0.2919913031358212 pour [[ 420  315]
#  [1291  687]]
# 	Temps cumulé : 74.8005268573761
#
# 	Itération 10 : h=0967 | w=0413
# 	Temps sliding_window x2 (334 généré): 0.0
# 	Temps de traitement pour 334 : 1.6985793113708496
# 	Temps d'extraction de features pour 334 : 0.540057897567749
# 	Temps de prédiction pour 334 : 1.4746198654174805
# 	Fenêtres gardées : 0 sur 334 (p>=0.5)
# 	Meilleur score de l'itération : 0.15073561258068915 pour [[ 420  280]
#  [1387  693]]
# 	Temps cumulé : 78.51528429985046
#
# 	Itération 11 : h=0107 | w=0060
# 	Temps sliding_window x2 (2126 généré): 0.002142667770385742
# 	Temps de traitement pour 2126 : 0.4114077091217041
# 	Temps d'extraction de features pour 2126 : 3.278831720352173
# 	Temps de prédiction pour 2126 : 8.728286266326904
# 	Fenêtres gardées : 4 sur 2126 (p>=0.5)
# 	Meilleur score de l'itération : 0.909273274064861 pour [[805 560]
#  [912 620]]
# 	Temps cumulé : 90.93595266342163
#
# 	Itération 12 : h=0202 | w=0114
# 	Temps sliding_window x2 (1870 généré): 0.00518345832824707
# 	Temps de traitement pour 1870 : 0.5593080520629883
# 	Temps d'extraction de features pour 1870 : 2.864715099334717
# 	Temps de prédiction pour 1870 : 8.068005084991455
# 	Fenêtres gardées : 7 sur 1870 (p>=0.5)
# 	Meilleur score de l'itération : 0.9830081654099326 pour [[455 490]
#  [657 604]]
# 	Temps cumulé : 102.43465113639832
#
# 	Itération 13 : h=0298 | w=0168
# 	Temps sliding_window x2 (1624 généré): 0.0
# 	Temps de traitement pour 1624 : 0.745685338973999
# 	Temps d'extraction de features pour 1624 : 2.528712272644043
# 	Temps de prédiction pour 1624 : 6.969484806060791
# 	Fenêtres gardées : 8 sur 1624 (p>=0.5)
# 	Meilleur score de l'itération : 0.9338112327957092 pour [[455 455]
#  [753 623]]
# 	Temps cumulé : 112.6789002418518
#
# 	Itération 14 : h=0393 | w=0222
# 	Temps sliding_window x2 (1342 généré): 0.0
# 	Temps de traitement pour 1342 : 0.9544880390167236
# 	Temps d'extraction de features pour 1342 : 2.032569646835327
# 	Temps de prédiction pour 1342 : 5.661444664001465
# 	Fenêtres gardées : 7 sur 1342 (p>=0.5)
# 	Meilleur score de l'itération : 0.8972143362005278 pour [[  70  805]
#  [ 463 1027]]
# 	Temps cumulé : 121.32740259170532
#
# 	Itération 15 : h=0489 | w=0277
# 	Temps sliding_window x2 (1182 généré): 0.0
# 	Temps de traitement pour 1182 : 1.7084546089172363
# 	Temps d'extraction de features pour 1182 : 1.7455859184265137
# 	Temps de prédiction pour 1182 : 4.8625807762146
# 	Fenêtres gardées : 7 sur 1182 (p>=0.5)
# 	Meilleur score de l'itération : 0.8934909677022956 pour [[  35  770]
#  [ 524 1047]]
# 	Temps cumulé : 129.64536499977112
#
# 	Itération 16 : h=0584 | w=0330
# 	Temps sliding_window x2 (938 généré): 0.0009984970092773438
# 	Temps de traitement pour 938 : 1.9349126815795898
# 	Temps d'extraction de features pour 938 : 1.360670566558838
# 	Temps de prédiction pour 938 : 3.8668322563171387
# 	Fenêtres gardées : 0 sur 938 (p>=0.5)
# 	Meilleur score de l'itération : 0.4120665596607072 pour [[ 630  210]
#  [1214  540]]
# 	Temps cumulé : 136.80877900123596
#
# 	Itération 17 : h=0680 | w=0385
# 	Temps sliding_window x2 (750 généré): 0.0
# 	Temps de traitement pour 750 : 2.299776315689087
# 	Temps d'extraction de features pour 750 : 1.1206457614898682
# 	Temps de prédiction pour 750 : 3.049654960632324
# 	Fenêtres gardées : 0 sur 750 (p>=0.5)
# 	Meilleur score de l'itération : 0.44003726637528623 pour [[ 595  175]
#  [1275  560]]
# 	Temps cumulé : 143.2792046070099
#
# 	Itération 18 : h=0775 | w=0439
# 	Temps sliding_window x2 (548 généré): 0.0
# 	Temps de traitement pour 548 : 2.2456748485565186
# 	Temps d'extraction de features pour 548 : 0.8028724193572998
# 	Temps de prédiction pour 548 : 2.2206838130950928
# 	Fenêtres gardées : 1 sur 548 (p>=0.5)
# 	Meilleur score de l'itération : 0.5703142672086338 pour [[ 595  280]
#  [1370  719]]
# 	Temps cumulé : 148.54901146888733
#
# ...
#  [1157  935]]
# 	Temps cumulé : 91.59016633033752
#
# 	Itération 12 : h=0202 | w=0114
# 	Temps sliding_window x2 (1870 généré): 0.001994609832763672
# 	Temps de traitement pour 1870 : 0.5925521850585938
# 	Temps d'extraction de features pour 1870 : 2.8718392848968506
# 	Temps de prédiction pour 1870 : 7.746702432632446
# 	Fenêtres gardées : 0 sur 1870 (p>=0.5)
# 	Meilleur score de l'itération : 0.48951616408557014 pour [[595 525]
#  [709 727]]
# 	Temps cumulé : 102.80525517463684
#
# 	Itération 13 : h=0298 | w=0168
# 	Temps sliding_window x2 (1624 généré): 0.002059459686279297
# 	Temps de traitement pour 1624 : 0.7473845481872559
# 	Temps d'extraction de features pour 1624 : 2.465984344482422
# 	Temps de prédiction pour 1624 : 6.728276491165161
# 	Fenêtres gardées : 0 sur 1624 (p>=0.5)
# 	Meilleur score de l'itération : 0.4047120726568806 pour [[665 245]
#  [963 413]]
# 	Temps cumulé : 112.77100419998169
#
# 	Itération 14 : h=0393 | w=0222
# 	Temps sliding_window x2 (1342 généré): 0.0
# 	Temps de traitement pour 1342 : 0.9660799503326416
# 	Temps d'extraction de features pour 1342 : 1.9998416900634766
# 	Temps de prédiction pour 1342 : 5.620102643966675
# 	Fenêtres gardées : 1 sur 1342 (p>=0.5)
# 	Meilleur score de l'itération : 0.5993762920345629 pour [[595 595]
#  [817 988]]
# 	Temps cumulé : 121.35702848434448
#
# 	Itération 15 : h=0489 | w=0277
# 	Temps sliding_window x2 (1182 généré): 0.0
# 	Temps de traitement pour 1182 : 1.7375867366790771
# 	Temps d'extraction de features pour 1182 : 1.8250064849853516
# 	Temps de prédiction pour 1182 : 4.98624324798584
# 	Fenêtres gardées : 0 sur 1182 (p>=0.5)
# 	Meilleur score de l'itération : 0.37276701236498994 pour [[1120  525]
#  [1397 1014]]
# 	Temps cumulé : 129.9116153717041
#
# 	Itération 16 : h=0584 | w=0330
# 	Temps sliding_window x2 (938 généré): 0.0009548664093017578
# 	Temps de traitement pour 938 : 1.96620512008667
# 	Temps d'extraction de features pour 938 : 1.4191625118255615
# 	Temps de prédiction pour 938 : 3.95797061920166
# 	Fenêtres gardées : 3 sur 938 (p>=0.5)
# 	Meilleur score de l'itération : 0.8371772240583274 pour [[ 595  595]
#  [1179  925]]
# 	Temps cumulé : 137.2591450214386
#
# 	Itération 17 : h=0680 | w=0385
# 	Temps sliding_window x2 (750 généré): 0.0
# 	Temps de traitement pour 750 : 2.3995859622955322
# 	Temps d'extraction de features pour 750 : 1.1230218410491943
# 	Temps de prédiction pour 750 : 3.195592164993286
# 	Fenêtres gardées : 0 sur 750 (p>=0.5)
# 	Meilleur score de l'itération : 0.35305448312019677 pour [[ 630  210]
#  [1310  595]]
# 	Temps cumulé : 143.98101091384888
#
# 	Itération 18 : h=0775 | w=0439
# 	Temps sliding_window x2 (548 généré): 0.0
# 	Temps de traitement pour 548 : 2.2875044345855713
# 	Temps d'extraction de features pour 548 : 0.8162236213684082
# 	Temps de prédiction pour 548 : 2.3416004180908203
# 	Fenêtres gardées : 5 sur 548 (p>=0.5)
# 	Meilleur score de l'itération : 0.9067391541741149 pour [[ 595  525]
#  [1370  964]]
# 	Temps cumulé : 149.43248796463013
#
# 	Itération 19 : h=0871 | w=0493
# 	Temps sliding_window x2 (412 généré): 0.0
# 	Temps de traitement pour 412 : 2.297523021697998
# 	Temps d'extraction de features pour 412 : 0.6245391368865967
# 	Temps de prédiction pour 412 : 1.7498483657836914
# 	Fenêtres gardées : 0 sur 412 (p>=0.5)
# 	Meilleur score de l'itération : 0.44591152212524116 pour [[ 595   70]
#  [1088  941]]
# 	Temps cumulé : 154.1069679260254
#
# 	Itération 20 : h=0967 | w=0547
# 	Temps sliding_window x2 (270 généré): 0.0
# 	Temps de traitement pour 270 : 1.9634721279144287
# 	Temps d'extraction de features pour 270 : 0.3989739418029785
# 	Temps de prédiction pour 270 : 1.1202619075775146
# 	Fenêtres gardées : 0 sur 270 (p>=0.5)
# 	Meilleur score de l'itération : 0.18438930956715843 pour [[ 595   35]
#  [1142 1002]]
# 	Temps cumulé : 157.59456086158752
#
# 	Itération 21 : h=0107 | w=0075
# 	Temps sliding_window x2 (2062 généré): 0.0047149658203125
# 	Temps de traitement pour 2062 : 0.498720645904541
# 	Temps d'extraction de features pour 2062 : 3.220254421234131
# 	Temps de prédiction pour 2062 : 8.474266290664673
# 	Fenêtres gardées : 2 sur 2062 (p>=0.5)
# 	Meilleur score de l'itération : 0.8567724906488046 pour [[1120  700]
#  [1195  807]]
# 	Temps cumulé : 169.7968065738678
#
# 	Itération 22 : h=0202 | w=0142
# 	Temps sliding_window x2 (1810 généré): 0.002012968063354492
# 	Temps de traitement pour 1810 : 0.6519620418548584
# 	Temps d'extraction de features pour 1810 : 2.783081293106079
# 	Temps de prédiction pour 1810 : 7.470019102096558
# 	Fenêtres gardées : 1 sur 1810 (p>=0.5)
# 	Meilleur score de l'itération : 0.5545061456580598 pour [[665 595]
#  [807 797]]
# 	Temps cumulé : 180.70594763755798
#
# 	Itération 23 : h=0298 | w=0210
# 	Temps sliding_window x2 (1570 généré): 0.000995635986328125
# 	Temps de traitement pour 1570 : 0.9043524265289307
# 	Temps d'extraction de features pour 1570 : 2.437621593475342
# 	Temps de prédiction pour 1570 : 6.611547231674194
# 	Fenêtres gardées : 3 sur 1570 (p>=0.5)
# 	Meilleur score de l'itération : 0.5757518756719976 pour [[665  70]
#  [875 368]]
# 	Temps cumulé : 190.67121362686157
#
# 	Itération 24 : h=0393 | w=0277
# 	Temps sliding_window x2 (1294 généré): 0.001177072525024414
# 	Temps de traitement pour 1294 : 1.3081772327423096
# 	Temps d'extraction de features pour 1294 : 1.9556331634521484
# 	Temps de prédiction pour 1294 : 5.459932565689087
# 	Fenêtres gardées : 2 sur 1294 (p>=0.5)
# 	Meilleur score de l'itération : 0.8032832547915715 pour [[ 595  630]
#  [ 872 1023]]
# 	Temps cumulé : 199.39911365509033
#
# 	Itération 25 : h=0489 | w=0344
# 	Temps sliding_window x2 (1094 généré): 0.0012912750244140625
# 	Temps de traitement pour 1094 : 1.816500186920166
# 	Temps d'extraction de features pour 1094 : 1.6652429103851318
# 	Temps de prédiction pour 1094 : 4.615180015563965
# 	Fenêtres gardées : 2 sur 1094 (p>=0.5)
# 	Meilleur score de l'itération : 0.9461703043223078 pour [[ 595  595]
#  [1084  939]]
# 	Temps cumulé : 207.50083374977112
#
# 	Itération 26 : h=0584 | w=0411
# 	Temps sliding_window x2 (862 généré): 0.0009353160858154297
# 	Temps de traitement pour 862 : 2.3010590076446533
# 	Temps d'extraction de features pour 862 : 1.2680933475494385
# 	Temps de prédiction pour 862 : 3.6325690746307373
# 	Fenêtres gardées : 7 sur 862 (p>=0.5)
# 	Meilleur score de l'itération : 0.9892136975604386 pour [[ 595  560]
#  [1179  971]]
# 	Temps cumulé : 214.70724201202393
#
# 	Itération 27 : h=0680 | w=0479
# 	Temps sliding_window x2 (654 généré): 0.0
# 	Temps de traitement pour 654 : 2.6632654666900635
# 	Temps d'extraction de features pour 654 : 0.988471269607544
# 	Temps de prédiction pour 654 : 2.7241532802581787
# 	Fenêtres gardées : 4 sur 654 (p>=0.5)
# 	Meilleur score de l'itération : 0.6791230540163729 pour [[ 595  560]
#  [1275 1039]]
# 	Temps cumulé : 221.08564233779907
#
# 	Itération 28 : h=0775 | w=0546
# 	Temps sliding_window x2 (470 généré): 0.0
# 	Temps de traitement pour 470 : 2.746910810470581
# 	Temps d'extraction de features pour 470 : 0.7051241397857666
# 	Temps de prédiction pour 470 : 1.9872207641601562
# 	Fenêtres gardées : 4 sur 470 (p>=0.5)
# 	Meilleur score de l'itération : 0.9363292119914627 pour [[ 595  455]
#  [1370 1001]]
# 	Temps cumulé : 226.52742528915405
#
# 	Itération 29 : h=0871 | w=0614
# 	Temps sliding_window x2 (346 généré): 0.00043010711669921875
# 	Temps de traitement pour 346 : 2.6728036403656006
# 	Temps d'extraction de features pour 346 : 0.4961118698120117
# 	Temps de prédiction pour 346 : 1.4500465393066406
# 	Fenêtres gardées : 2 sur 346 (p>=0.5)
# 	Meilleur score de l'itération : 0.8321950590351226 pour [[ 560   70]
#  [1174  941]]
# 	Temps cumulé : 231.15349078178406
#
# 	Itération 30 : h=0967 | w=0682
# 	Temps sliding_window x2 (206 généré): 0.0
# 	Temps de traitement pour 206 : 2.106058359146118
# 	Temps d'extraction de features pour 206 : 0.297407865524292
# 	Temps de prédiction pour 206 : 0.8540017604827881
# 	Fenêtres gardées : 0 sur 206 (p>=0.5)
# 	Meilleur score de l'itération : 0.2773367545303299 pour [[ 560   70]
#  [1242 1037]]
# 	Temps cumulé : 234.41564631462097
#
# 	Itération 31 : h=0107 | w=0090
# 	Temps sliding_window x2 (2062 généré): 0.0009391307830810547
# 	Temps de traitement pour 2062 : 0.4842350482940674
# 	Temps d'extraction de features pour 2062 : 3.21795654296875
# 	Temps de prédiction pour 2062 : 8.561697006225586
# 	Fenêtres gardées : 1 sur 2062 (p>=0.5)
# 	Meilleur score de l'itération : 0.6195062374366636 pour [[665 210]
#  [755 317]]
# 	Temps cumulé : 246.68460774421692
#
# 	Itération 32 : h=0202 | w=0170
# 	Temps sliding_window x2 (1810 généré): 0.0005636215209960938
# 	Temps de traitement pour 1810 : 0.7474613189697266
# 	Temps d'extraction de features pour 1810 : 2.891275644302368
# 	Temps de prédiction pour 1810 : 7.657510995864868
# 	Fenêtres gardées : 1 sur 1810 (p>=0.5)
# 	Meilleur score de l'itération : 0.6458976386731565 pour [[665 245]
#  [867 415]]
# 	Temps cumulé : 257.98524928092957
#
# 	Itération 33 : h=0298 | w=0251
# 	Temps sliding_window x2 (1462 généré): 0.003900289535522461
# 	Temps de traitement pour 1462 : 1.0366272926330566
# 	Temps d'extraction de features pour 1462 : 2.332691192626953
# 	Temps de prédiction pour 1462 : 6.146782159805298
# 	Fenêtres gardées : 3 sur 1462 (p>=0.5)
# 	Meilleur score de l'itération : 0.665037563749059 pour [[595 595]
#  [846 893]]
# 	Temps cumulé : 267.52156376838684
#
# 	Itération 34 : h=0393 | w=0331
# 	Temps sliding_window x2 (1198 généré): 0.003989219665527344
# 	Temps de traitement pour 1198 : 1.9455764293670654
# 	Temps d'extraction de features pour 1198 : 1.9103963375091553
# 	Temps de prédiction pour 1198 : 4.975486993789673
# 	Fenêtres gardées : 6 sur 1198 (p>=0.5)
# 	Meilleur score de l'itération : 0.8721727085892129 pour [[ 735  595]
#  [1128  926]]
# 	Temps cumulé : 276.3576195240021
#
# 	Itération 35 : h=0489 | w=0412
# 	Temps sliding_window x2 (1006 généré): 0.0
# 	Temps de traitement pour 1006 : 2.305790901184082
# 	Temps d'extraction de features pour 1006 : 1.5654263496398926
# 	Temps de prédiction pour 1006 : 4.161624193191528
# 	Fenêtres gardées : 6 sur 1006 (p>=0.5)
# 	Meilleur score de l'itération : 0.9708427754962304 pour [[ 595  560]
#  [1084  972]]
# 	Temps cumulé : 284.39219403266907
#
# 	Itération 36 : h=0584 | w=0493
# 	Temps sliding_window x2 (748 généré): 0.0
# 	Temps de traitement pour 748 : 2.5791428089141846
# 	Temps d'extraction de features pour 748 : 1.1430377960205078
# 	Temps de prédiction pour 748 : 3.114274501800537
# 	Fenêtres gardées : 4 sur 748 (p>=0.5)
# 	Meilleur score de l'itération : 0.9780852282223039 pour [[ 595  525]
#  [1179 1018]]
# 	Temps cumulé : 291.233815908432
#
# 	Itération 37 : h=0680 | w=0574
# 	Temps sliding_window x2 (558 généré): 0.0
# 	Temps de traitement pour 558 : 3.044116258621216
# 	Temps d'extraction de features pour 558 : 0.8788282871246338
# 	Temps de prédiction pour 558 : 2.3249409198760986
# 	Fenêtres gardées : 4 sur 558 (p>=0.5)
# 	Meilleur score de l'itération : 0.6611460569826806 pour [[ 630  245]
#  [1204  925]]
# 	Temps cumulé : 297.4929304122925
#
# 	Itération 38 : h=0775 | w=0654
# 	Temps sliding_window x2 (392 généré): 0.0
# 	Temps de traitement pour 392 : 2.9608092308044434
# 	Temps d'extraction de features pour 392 : 0.5783421993255615
# 	Temps de prédiction pour 392 : 1.6833748817443848
# 	Fenêtres gardées : 3 sur 392 (p>=0.5)
# 	Meilleur score de l'itération : 0.8695850085554591 pour [[ 595  385]
#  [1370 1039]]
# 	Temps cumulé : 302.72116446495056
#
# 	Itération 39 : h=0871 | w=0735
# 	Temps sliding_window x2 (280 généré): 0.0
# 	Temps de traitement pour 280 : 2.8666276931762695
# 	Temps d'extraction de features pour 280 : 0.3887064456939697
# 	Temps de prédiction pour 280 : 1.1749942302703857
# 	Fenêtres gardées : 1 sur 280 (p>=0.5)
# 	Meilleur score de l'itération : 0.5095404120197634 pour [[ 490   70]
#  [1225  941]]
# 	Temps cumulé : 307.1578059196472
#
# 	Itération 40 : h=0967 | w=0816
# 	Temps sliding_window x2 (142 généré): 0.0
# 	Temps de traitement pour 142 : 1.9996814727783203
# 	Temps d'extraction de features pour 142 : 0.21025371551513672
# 	Temps de prédiction pour 142 : 0.5895507335662842
# 	Fenêtres gardées : 0 sur 142 (p>=0.5)
# 	Meilleur score de l'itération : 0.05350310081985005 pour [[ 420   70]
#  [1236 1037]]
# 	Temps cumulé : 309.95729184150696
#
# 	Itération 41 : h=0107 | w=0105
# 	Temps sliding_window x2 (2062 généré): 0.0
# 	Temps de traitement pour 2062 : 0.5145273208618164
# 	Temps d'extraction de features pour 2062 : 3.4310638904571533
# 	Temps de prédiction pour 2062 : 8.650036334991455
# 	Fenêtres gardées : 1 sur 2062 (p>=0.5)
# 	Meilleur score de l'itération : 0.70384559480555 pour [[875 560]
#  [982 665]]
# 	Temps cumulé : 322.5562844276428
#
# 	Itération 42 : h=0202 | w=0198
# 	Temps sliding_window x2 (1750 généré): 0.002061605453491211
# 	Temps de traitement pour 1750 : 0.7125606536865234
# 	Temps d'extraction de features pour 1750 : 2.608072280883789
# 	Temps de prédiction pour 1750 : 7.2334043979644775
# 	Fenêtres gardées : 4 sur 1750 (p>=0.5)
# 	Meilleur score de l'itération : 0.8475499059837798 pour [[665 245]
#  [867 443]]
# 	Temps cumulé : 333.11739587783813
#
# 	Itération 43 : h=0298 | w=0293
# 	Temps sliding_window x2 (1408 généré): 0.0009965896606445312
# 	Temps de traitement pour 1408 : 1.0838098526000977
# 	Temps d'extraction de features pour 1408 : 2.1727352142333984
# 	Temps de prédiction pour 1408 : 5.80961799621582
# 	Fenêtres gardées : 3 sur 1408 (p>=0.5)
# 	Meilleur score de l'itération : 0.7407666838434915 pour [[700 630]
#  [998 923]]
# 	Temps cumulé : 342.18661308288574
#
# 	Itération 44 : h=0393 | w=0386
# 	Temps sliding_window x2 (1102 généré): 0.001079559326171875
# 	Temps de traitement pour 1102 : 1.9146583080291748
# 	Temps d'extraction de features pour 1102 : 1.653503179550171
# 	Temps de prédiction pour 1102 : 4.650616884231567
# 	Fenêtres gardées : 7 sur 1102 (p>=0.5)
# 	Meilleur score de l'itération : 0.8369531405410197 pour [[ 630  560]
#  [1023  946]]
# 	Temps cumulé : 350.4135890007019
#
# 	Itération 45 : h=0489 | w=0480
# 	Temps sliding_window x2 (918 généré): 0.0010018348693847656
# 	Temps de traitement pour 918 : 2.6038432121276855
# 	Temps d'extraction de features pour 918 : 1.3730251789093018
# 	Temps de prédiction pour 918 : 3.8828413486480713
# 	Fenêtres gardées : 4 sur 918 (p>=0.5)
# 	Meilleur score de l'itération : 0.9666411960079967 pour [[ 595  560]
#  [1084 1040]]
# 	Temps cumulé : 358.27840304374695
#
# 	Itération 46 : h=0584 | w=0574
# 	Temps sliding_window x2 (672 généré): 0.0007777214050292969
# 	Temps de traitement pour 672 : 2.9570987224578857
# 	Temps d'extraction de features pour 672 : 0.9614450931549072
# 	Temps de prédiction pour 672 : 2.82419753074646
# 	Fenêtres gardées : 3 sur 672 (p>=0.5)
# 	Meilleur score de l'itération : 0.9169362672137903 pour [[ 595  455]
#  [1179 1029]]
# 	Temps cumulé : 365.0253095626831
#
# 	Itération 47 : h=0680 | w=0668
# 	Temps sliding_window x2 (462 généré): 0.0010828971862792969
# 	Temps de traitement pour 462 : 3.0408291816711426
# 	Temps d'extraction de features pour 462 : 0.6849119663238525
# 	Temps de prédiction pour 462 : 1.9641973972320557
# 	Fenêtres gardées : 1 sur 462 (p>=0.5)
# 	Meilleur score de l'itération : 0.5566305169244526 pour [[ 595  245]
#  [1263  925]]
# 	Temps cumulé : 370.7203471660614
#
# 	Itération 48 : h=0775 | w=0761
# 	Temps sliding_window x2 (314 généré): 0.0
# 	Temps de traitement pour 314 : 2.8825185298919678
# 	Temps d'extraction de features pour 314 : 0.49286818504333496
# 	Temps de prédiction pour 314 : 1.313652515411377
# 	Fenêtres gardées : 2 sur 314 (p>=0.5)
# 	Meilleur score de l'itération : 0.7694875216892446 pour [[ 595  280]
#  [1370 1041]]
# 	Temps cumulé : 375.416818857193
#
# 	Itération 49 : h=0871 | w=0856
# 	Temps sliding_window x2 (192 généré): 0.0009965896606445312
# 	Temps de traitement pour 192 : 2.354461193084717
# 	Temps d'extraction de features pour 192 : 0.27593445777893066
# 	Temps de prédiction pour 192 : 0.8167219161987305
# 	Fenêtres gardées : 0 sur 192 (p>=0.5)
# 	Meilleur score de l'itération : 0.12419819708303956 pour [[ 350   70]
#  [1206  941]]
# 	Temps cumulé : 378.8736310005188
#
# 	Itération 50 : h=0967 | w=0950
# 	Temps sliding_window x2 (78 généré): 0.0
# 	Temps de traitement pour 78 : 1.271174430847168
# 	Temps d'extraction de features pour 78 : 0.1249537467956543
# 	Temps de prédiction pour 78 : 0.3259260654449463
# 	Fenêtres gardées : 0 sur 78 (p>=0.5)
# 	Meilleur score de l'itération : 0.026714994145596263 pour [[ 315    0]
#  [1265  967]]
# 	Temps cumulé : 380.6022861003876
#
# Temps total de détection : 380.60338711738586
